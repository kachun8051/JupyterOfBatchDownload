# %% [markdown]
# <h2>Download Async by Class</h2>

# %%
import asyncio
import aiohttp
import os
from tqdm.notebook import tqdm
import nest_asyncio
from datetime import datetime
import os

class clsImageDownloader:
    # constructor
    def __init__(self):        
        self.image_urls = []
        self.image_folder = ""
        nest_asyncio.apply()
    # set parameters
    def setImageUrl(self, _url: str, _ext: str=".jpg", _min: int=1, _max: int=1):        
        self.image_urls = [ _url + self.threedigit(x) + _ext for x in range(_min, _max+1)]
        # for x in range(_min, _max+1):
        #     self.image_urls.append(_url + self.threedigit(x) + _ext)
    # set parameters
    def setImageFolder(self, _folder: str = ""):
        self.image_folder = _folder
    @staticmethod
    def threedigit(num: int) -> str:
        if num > 999:
            return num
        if num < 10:
            return f"00{str(num)}"
        if num < 100:
            return f"0{str(num)}"
        return str(num)
    @staticmethod
    def CreateFolderIfNotExist(_folder: str) -> bool:
        # Check whether the specified path exists or not
        isExist = os.path.exists(_folder)
        if isExist == True:
            return True
        else:
            # Create a new directory because it does not exist
            try:
                os.makedirs(_folder)
                print(f"The new directory {_folder} is created.")
                return True
            except:
                print(f"The directory {_folder} is NOT created!")
                return False
                
    @staticmethod
    def getNowTime():
        now = datetime.now()
        # dd/mm/YY H:M:S
        dt = now.strftime("%d/%m/%Y %H:%M:%S")
        return dt
    
    async def download_image2(self, _url: str, _subfolder: str = ""):
        async with aiohttp.ClientSession() as session:
            async with session.get(_url) as response:
                fName = _url.split("/")[-1]
                if _subfolder == "":
                    fPath = 'C://Temp//all_images//'
                else:
                    fPath = f'C://Temp//all_images//{_subfolder}//'
                with open(fPath + fName, 'wb') as f:
                    while True:
                        chunk = await response.content.read(1024)
                        if not chunk:
                            break
                        f.write(chunk)
                    print(fName, " is downloaded at: ", self.getNowTime(), ".")
                    
    def runIt(self) -> bool:
        isFolderExist_1 = self.CreateFolderIfNotExist('C://Temp')
        if isFolderExist_1 == False:
            return False
        isFolderExist_2 = self.CreateFolderIfNotExist('C://Temp//all_images')
        if isFolderExist_2 == False:
            return False
        isFolderExist_3 = self.CreateFolderIfNotExist('C://Temp//all_images//' + self.image_folder)
        if isFolderExist_3 == False:
            return False
        tasks = [self.download_image2(url, self.image_folder) for url in self.image_urls]
        asyncio.get_event_loop().run_until_complete(asyncio.gather(*tasks))
        return True

# %%
obj = clsImageDownloader()
# 0425.jpg
obj.setImageUrl("http://www.globalphotos.org/hongkong/2023/1024/IMG_0", ".jpg", 425, 495)
obj.setImageFolder("airside_image")
isFetched = obj.runIt()
print("Is Fetched? ", isFetched)
# Out:
# The new directory C://Temp//all_images//airside_image is created.
# IMG_0442.jpg  is downloaded at:  01/09/2024 04:27:36 .
# IMG_0454.jpg  is downloaded at:  01/09/2024 04:27:36 .
# IMG_0445.jpg  is downloaded at:  01/09/2024 04:27:36 .
# IMG_0480.jpg  is downloaded at:  01/09/2024 04:27:36 .
# IMG_0492.jpg  is downloaded at:  01/09/2024 04:27:36 .
# IMG_0433.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0444.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0448.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0447.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0435.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0425.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0464.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0446.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0456.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0490.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0489.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0453.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0452.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0440.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0476.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0432.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0449.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0459.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0437.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0426.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0443.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0428.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0482.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0427.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0470.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0431.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0483.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0471.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0493.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0487.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0484.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0436.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0458.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0438.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0462.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0460.jpg  is downloaded at:  01/09/2024 04:27:37 .
# IMG_0478.jpg  is downloaded at:  01/09/2024 04:27:38 .
# IMG_0466.jpg  is downloaded at:  01/09/2024 04:27:38 .
# IMG_0491.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0495.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0494.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0488.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0479.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0455.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0485.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0473.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0430.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0468.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0434.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0481.jpg  is downloaded at:  01/09/2024 04:27:41 .
# IMG_0465.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0463.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0486.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0450.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0472.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0474.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0457.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0461.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0469.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0429.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0477.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0467.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0475.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0451.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0439.jpg  is downloaded at:  01/09/2024 04:27:42 .
# IMG_0441.jpg  is downloaded at:  01/09/2024 04:27:42 .
# Is Fetched?  True

# %% [markdown]
# <h2>Import custom class</h2>

# %%
from AsyncDownloader import clsImageDownloader  # Importing the class
obj = clsImageDownloader()
# 0425.jpg
obj.setImageUrl("http://www.globalphotos.org/hongkong/2023/1024/IMG_0", ".jpg", 425, 495)
obj.setImageFolder("airside_image")
isFetched = obj.runIt()
print("Is Fetched? ", isFetched)
# Out:
# The new directory C://Temp//all_images//airside_image is created.
# IMG_0436.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0454.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0484.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0445.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0492.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0487.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0493.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0480.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0442.jpg  is downloaded at:  01/09/2024 04:39:13 .
# IMG_0429.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0434.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0440.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0450.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0443.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0426.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0453.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0489.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0495.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0478.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0437.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0494.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0483.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0432.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0477.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0481.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0488.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0491.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0465.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0471.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0452.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0475.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0463.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0474.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0439.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0479.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0469.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0438.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0447.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0473.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0430.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0459.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0472.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0456.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0476.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0466.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0460.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0435.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0485.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0444.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0461.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0486.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0482.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0427.jpg  is downloaded at:  01/09/2024 04:39:14 .
# IMG_0458.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0441.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0433.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0448.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0468.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0446.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0449.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0457.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0428.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0451.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0431.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0467.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0470.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0425.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0455.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0490.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0464.jpg  is downloaded at:  01/09/2024 04:39:15 .
# IMG_0462.jpg  is downloaded at:  01/09/2024 04:39:16 .
# Is Fetched?  True
